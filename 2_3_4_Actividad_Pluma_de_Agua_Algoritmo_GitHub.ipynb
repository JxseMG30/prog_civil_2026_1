# %% [markdown]
# <a href="https://colab.research.google.com/github/JxseMG30/prog_civil_2026_1/blob/main/2_3_4_Actividad_Pluma_de_Agua_Algoritmo_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NOMBRES COMPLETOS: Jose David Mercado Gomez
# # Código: 1103102744

# %% [markdown]
# # Actividad de Programación con Python
# ## **Historia, ciencia y programación: la “pluma de agua”**
#
# > **Relato de partida**
# > **¿Por qué los costeños le decimos “pluma” a la llave del agua?**
# >
# > En el Caribe colombiano, abrir la “pluma” no es solo una acción cotidiana: es una expresión cargada de historia, técnica y cultura. Aunque algunos se sorprendan o incluso se burlen del término, lo cierto es que decir “pluma” en vez de “llave” no es un error, sino una herencia viva que conecta nuestro lenguaje con siglos de evolución hidráulica.
# >
# > Mucho antes de que existieran los grifos modernos, el agua se distribuía mediante sistemas regulados con precisión. En España, por ejemplo, se usaba la **“pluma de agua”** como unidad de medida para calcular el caudal que se entregaba a cada hogar. Aproximadamente, una pluma equivalía a **0.025 litros por segundo**. En algunos lugares, ese flujo se regulaba mediante orificios calibrados y dispositivos llamados **plumeros**, que permitían controlar la salida del agua.
# >
# > Durante la época colonial, muchas de estas prácticas técnicas cruzaron el Atlántico y llegaron a ciudades como Cartagena, Barranquilla y Santa Marta. Con el tiempo, el término “pluma” dejó de ser solamente técnico y pasó al habla cotidiana como sinónimo de la llave del agua.
# >
# > Así, una palabra del uso diario conserva una memoria histórica, tecnológica y cultural.
# >
# > ---
# >
# > **Idea central para esta actividad:**
# > A partir de este relato, construiremos un problema de programación donde una magnitud histórica y física, el **caudal de una pluma de agua**, se represente mediante variables, operaciones y estructuras básicas de Python.

# %% [markdown]
# # Actividad de Programación con Python
#
# ## Historia, ciencia y programación: la “pluma de agua”
#
# ### Nombre:
# Jose David Mercado Gomez
#
# ### Código:
# 1103102744
#
# ---
#
# ## Propósito general del programa
#
# El objetivo del programa es calcular el consumo de agua de un hogar a partir del número de “plumas de agua” asignadas.
#
# El sistema permite calcular:
#
# - el caudal total en litros por segundo;
# - el consumo diario;
# - el consumo mensual;
# - y el nivel de consumo.
#
# Este ejercicio relaciona historia, cultura, ingeniería y programación mediante Python.

# %%
# ======================================================
# ACTIVIDAD: MODELAR LA "PLUMA DE AGUA" CON PYTHON
# ======================================================

# Nombre: Jose David Mercado Gomez
# Código: 1103102744

# ------------------------------------------------------
# 1. Solicitar al usuario el número de plumas
# ------------------------------------------------------

# input() permite ingresar datos desde el teclado
# int() convierte el dato ingresado en número entero

plumas = int(input("Ingrese el número de plumas: "))

# ------------------------------------------------------
# 2. Definir constantes del problema
# ------------------------------------------------------

# Cantidad de litros por segundo
# que suministra una pluma de agua

CAUDAL_PLUMA = 0.025

# Cantidad de segundos que tiene un día

SEGUNDOS_DIA = 86400

# ------------------------------------------------------
# 3. Calcular el caudal total
# ------------------------------------------------------

# Se multiplica la cantidad de plumas
# por el caudal de cada una

caudal_total = plumas * CAUDAL_PLUMA

# ------------------------------------------------------
# 4. Calcular el consumo diario
# ------------------------------------------------------

# Se multiplica el caudal total
# por los segundos del día

consumo_diario = caudal_total * SEGUNDOS_DIA

# ------------------------------------------------------
# 5. Calcular el consumo mensual
# ------------------------------------------------------

# Se asume un mes de 30 días

consumo_mensual = consumo_diario * 30

# ------------------------------------------------------
# 6. Clasificar el consumo
# ------------------------------------------------------

# Se utiliza una estructura condicional
# para clasificar el nivel de consumo

if consumo_diario < 1000:
    nivel_consumo = "Bajo"

elif 1000 <= consumo_diario <= 3000:
    nivel_consumo = "Medio"

else:
    nivel_consumo = "Alto"

# ------------------------------------------------------
# 7. Mostrar resultados
# ------------------------------------------------------

# print() muestra información en pantalla
# :.2f limita los decimales a dos cifras

print("\n========== RESULTADOS ==========")

print(f"Caudal total: {caudal_total:.2f} litros/segundo")

print(f"Consumo diario: {consumo_diario:.2f} litros")

print(f"Consumo mensual: {consumo_mensual:.2f} litros")

print(f"Nivel de consumo: {nivel_consumo}")
# Out:
# Ingrese el número de plumas: 2
#
# ========== RESULTADOS ==========
# Caudal total: 0.05 litros/segundo
# Consumo diario: 4320.00 litros
# Consumo mensual: 129600.00 litros
# Nivel de consumo: Alto

# %% [markdown]
# # Explicación detallada del código
#
# ## Entrada de datos
#
# ```python
# plumas = int(input("Ingrese el número de plumas: "))

# %% [markdown]
# Explicación
#
# input() permite ingresar datos desde el teclado.
#
# int() convierte el valor ingresado en número entero.
#
# La variable plumas almacena la cantidad de plumas de agua.

# %% [markdown]
# #Definición de constantes

# %%
CAUDAL_PLUMA = 0.025
SEGUNDOS_DIA = 86400

# %% [markdown]
# Explicación
#
# CAUDAL_PLUMA representa el caudal de una pluma de agua en litros por segundo.
#
# SEGUNDOS_DIA representa la cantidad de segundos que tiene un día.

# %% [markdown]
# #Cálculo del caudal total

# %%
caudal_total = plumas * CAUDAL_PLUMA

# %% [markdown]
# Explicación
#
# Se multiplica la cantidad de plumas por el caudal de cada una para obtener el caudal total.

# %% [markdown]
# #Cálculo del consumo diario

# %%
consumo_diario = caudal_total * SEGUNDOS_DIA

# %% [markdown]
# Explicación
#
# Se multiplica el caudal total por los segundos del día para calcular el consumo diario.

# %% [markdown]
# #Cálculo del consumo mensual

# %%
consumo_mensual = consumo_diario * 30

# %% [markdown]
# Explicación
#
# Se multiplica el consumo diario por 30 para estimar el consumo mensual.

# %% [markdown]
# #Estructura condicional

# %%
if consumo_diario < 1000:
    nivel_consumo = "Bajo"

elif 1000 <= consumo_diario <= 3000:
    nivel_consumo = "Medio"

else:
    nivel_consumo = "Alto"

# %% [markdown]
# Explicación
#
# La estructura if - elif - else permite clasificar el nivel de consumo según la cantidad de litros consumidos por día.

# %% [markdown]
# #Mostrar resultados

# %%
print(f"Caudal total: {caudal_total:.2f} litros/segundo")
# Out:
# Caudal total: 0.05 litros/segundo

# %% [markdown]
# Explicación
#
# print() muestra información en pantalla.
#
# :.2f limita los números decimales a dos cifras.

# %% [markdown]
# # Variables utilizadas
#
# | Variable | Descripción |
# |---|---|
# | `plumas` | Número de plumas ingresadas por el usuario |
# | `CAUDAL_PLUMA` | Caudal de una pluma en litros por segundo |
# | `SEGUNDOS_DIA` | Cantidad de segundos que tiene un día |
# | `caudal_total` | Caudal total del sistema |
# | `consumo_diario` | Cantidad de agua consumida por día |
# | `consumo_mensual` | Cantidad de agua consumida por mes |
# | `nivel_consumo` | Clasificación del consumo |
#
# ---
#
# # Entradas, procesos y salidas
#
# ## Entrada
#
# El programa recibe el número de plumas de agua ingresadas por el usuario.
#
# ---
#
# ## Procesos
#
# El programa realiza:
# - cálculo del caudal total;
# - cálculo del consumo diario;
# - cálculo del consumo mensual;
# - clasificación del consumo.
#
# ---
#
# ## Salidas
#
# El programa muestra:
# - caudal total;
# - consumo diario;
# - consumo mensual;
# - nivel de consumo.

# %% [markdown]
# # Verificación conceptual
#
# ## 1. ¿Qué representa físicamente la variable principal del problema?
#
# La variable principal representa la cantidad de plumas de agua asignadas a un hogar y permite calcular el caudal y el consumo de agua.
#
# ---
#
# ## 2. ¿Por qué este ejercicio conecta historia, cultura e ingeniería?
#
# Porque utiliza una expresión tradicional del Caribe colombiano y la relaciona con conceptos físicos e hidráulicos mediante programación en Python.
#
# ---
#
# ## 3. ¿Qué operaciones aritméticas fueron necesarias?
#
# Se utilizaron multiplicaciones para calcular el caudal total, el consumo diario y el consumo mensual.
#
# ---
#
# ## 4. ¿Qué estructura condicional utilizó y por qué?
#
# Se utilizó la estructura `if - elif - else` para clasificar el consumo según la cantidad de litros consumidos por día.
#
# ---
#
# ## 5. ¿Cómo interpretaría el resultado en un contexto real?
#
# El resultado permite estimar el consumo de agua de un hogar y comprender mejor el uso del recurso hídrico.

# %% [markdown]
# # Reflexión final
#
# En esta actividad aprendí a relacionar conceptos históricos y físicos con programación en Python. También comprendí cómo calcular el consumo de agua utilizando variables, operaciones matemáticas y estructuras condicionales.
#
# La parte más difícil fue interpretar cómo transformar el caudal en consumo diario y mensual. Sin embargo, el ejercicio permitió fortalecer mis conocimientos sobre lógica de programación y documentación de código.
#
# Además, entendí la importancia de utilizar GitHub y herramientas tecnológicas para organizar proyectos y controlar versiones del trabajo.
